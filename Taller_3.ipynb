# %% [markdown]
# ## Taller 3 Cinepython
#
# ### Diplomado Python aplicado a la ingeniería
#
# - Wendy Mendoza Barrera
# - ID: 502216
# - Email:wendy.mendozab@upb.edu.co
#
#
# - Angela Posso Diaz
# - ID: 502224
# - Email:angela.posso@upb.edu.co
#
#
# - Adriana Suares Ballesteros
# - ID: 502197
# - Email:adriana.suarezb@upb.edu.co

# %% [markdown]
# Para el Ejercicio: Se hizo la creación de listas y diccionarios para guardar los datos de las peliculas, series y las comidas de los distintos restaurantes. Se creó una función para guardar el archivo .txt que generará la factura y al mismo tiempo esta también se mostrará al final de digitar los datos, luego se crearón más funciones para que guardaran la selección ya sea de peliculas o series y otras para la elección de comida en cada restaurante(McDonals, El Corral o Cinepython). Otras funciones también fueron creadas para hacer los clculos del precio, por el tiempo que se verá la pelicula y el cargo extra por la comida. funcion_tipoSala() fue creada para definir la sala que escogerá el usuario, ya sea una sala básica, medium o premiun y también a partir de esta se creó la función para asignar las salas a los clientes. Finalmente se crearon las funciones para llenar y mostrar, lo que estaría incluido en la factura que se le devolverá al usuario.

# %%
from io import open

nueva=[] # lista donde se va guardar los datos de una reservacion
listaPeliculas=[[1, "Los croods 2", "Pelicula"], [2, "Tom y Jerry", "Pelicula"], [3, "Rambo", "Pelicula"],
                [4, "Shrek", "Pelicula"],[5, "Juego del calamar", "Serie"], [6, "La casa de papel", "Serie"],[7, "Palpito", "Serie"]]

dicComida={1:["Combo Croissant Huevo Y Tocineta Con Hashbrown", "tu Combo viene acompañado de Croissant Relleno de huevos revueltos y tocineta con Hashbrown y Café 12oz", 10000, "McDonals"],
             2:["Combo Pancakes con Hashbrown", "Tu Combo viene acompañado de tres pancakes con salsa syrup y Café 12oz", 9000, "McDonals"],
             3:["1 Cajita Feliz de Nuggets", "1 Cajita Feliz de Nuggets +1 McCombo de Hamburguesa McNifica con Coca-Cola sin azúcar 1.75 ", 14000, "McDonals"],
             4:["Vaquero Callejero en combo","perro caliente con salchicha de 125 g a la parrilla, papa callejera, cebolla picada y salsas en pan perro + papas medianas (Corral o cascos) + bebida PET", 12000, "McDonals"],
             5:["Pollo Cebollitas Crunchy en combo", "Hamburguesa de 154 g de pechuga de pollo en salsa BBQ, con cebolla crujiente, lechuga en julianas, salsa BBQ y salsa miel mostaza en pan ajonjolí + papas medianas (Corral o cascos) + bebida PET", 12000, "McDonals"],
             6:["Pollo 1", "Pollo 1 Cebollitas Crunchy en combo", 10000,"El Corral"],
             7:["Pollo 2", "Pollo 2 Cebollitas Crunchy en combo", 11000,"El Corral"],
             8:["Pollo 3", "Pollo 3 Cebollitas Crunchy en combo", 13000,"El Corral"],
             9:["Pollo 4", "Pollo 4 Cebollitas Crunchy en combo", 14000, "El Corral"],
             10:["Pollo 5", "Pollo 5 Cebollitas Crunchy en combo", 12000, "El Corral"],
             11:["COMBO 1", "palomitas de maiz + gaseosa + perro caliente", 10000,"CinePython"],
             12:["COMBO 2", "palomitas de maiz + gaseosa + perro caliente", 15000,"CinePython"],
             13:["COMBO 3", "palomitas de maiz + gaseosa + perro caliente", 11000,"CinePython"],
             14:["COMBO 4", "palomitas de maiz + gaseosa + perro caliente", 14000,"CinePython"],
             15:["COMBO 5", "palomitas de maiz + gaseosa + perro caliente", 13000,"CinePython"]}

dicSala={1:(10, 40000), 2:(25, 80000), 3:(50, 100000), 4:(70, 150000), 5:(200, 150000), 5:(1000, 200000)}

def funcionPdf(aux, nombre):
    archivo=open(f"{nombre}.txt","w")
    archivo.write(aux)
    archivo.close()

# funcion para seleccionar una pelicula
def funcion_peliculas(lista):
    opcion =True
    pelicula=""
    while opcion:
        print("\tPeliculas y Series Disponibles")
        print("1. Los croods 2\n2. Tom y Jerry\n3. Rambo \n4. Shrek\n5. Juego del calamar 2\n6. La casa de papel\n7. palpito")
        opcion = int(input("Seleccione una Pelicula del 1 al 7: "))
        for i in range(len(lista)):
            if opcion>0 and opcion<=7:
                if lista[i][0]==opcion:
                    pelicula=lista[i]
                    opcion=False
    return pelicula
       
# funcion para calcular el total de a pagar por el alquiler de la pelicula
def funcion_total_alquiler(tiempo, precio):
    total=tiempo*precio
    return total
 
# funcion para seleccionar una comida
def comidasMAcdonal(lista):
    opcion =True
    pos=""
    while opcion==True:
        print("\tMenu Macdonals")
        print("1. Combo Croissant Huevo Y Tocineta Con Hashbrown 2")
        print("2. Combo Pancakes con Hashbrown")
        print("3. 1 Cajita Feliz de Nuggets")
        print("4. Vaquero Callejero en combo")
        print("5. Pollo Cebollitas Crunchy en combo\n")
        op=int(input("Seleccione un combo de1 1 a 5: "))
        for i in lista.keys():
            if op>0 and op<=5:
                if i==op:
                    opcion=False
                    return lista[i]    
                
def comidasCorral(lista):
    opcion =True
    pos=""
    while opcion==True:
        print("\tMenu Corral")
        print("1. (combo) Pollo 1 Cebollitas Crunchy en combo $10.000")
        print("2. (combo) Pollo 2 Cebollitas Crunchy en combo $11.000")
        print("3. (combo) Pollo 3 Cebollitas Crunchy en combo $13.000")
        print("4. (combo) Pollo 4 Cebollitas Crunchy en combo $14.000")
        print("5. (combo) Pollo 5 Cebollitas Crunchy en combo $12.000\n")
        op = int(input("Seleccione un combo de1 1 a 5: "))
        for i in lista.keys():
            if op>0 and op<=5:
                if i==op:
                    opcion=False
                    return lista[i+5]
        
def comidasCinepython(lista):
    opcion=True
    pos=0
    while opcion==True:
        print("\tMenu Cine-Python")
        print("1. COMBO 1 palomitas de maiz + gaseosa + perro caliente precio $10.000")
        print("2. COMBO 2 palomitas de maiz + gaseosa + perro caliente precio $15.000")
        print("3. COMBO 3 palomitas de maiz + gaseosa + perro caliente precio $11.000")
        print("4. COMBO 4 palomitas de maiz + gaseosa + perro caliente precio $14.000")
        print("5. COMBO 5 palomitas de maiz + gaseosa + perro caliente precio $13.000\n")
        op = int(input("Seleccione un combo de1 1 a 5: "))
        for i in lista.keys():
            if op>0 and op<=5:
                if i==op:
                    opcion=False
                    return lista[i+10]

def funcion_tipoSala():
    opcion=True
    tipo=""
    while opcion:
        print("\tTipos de Sala\n1. Premium\n2. Medium\n3. Basica")
        op=int(input("Selecione una opcion del 1 al 3: "))
        if op>0 and op<=3:
            if op==1:
                tipo=["Premium", 2]
            elif op==2:
                tipo=["Medium", 1.5]
            elif op==3:
                tipo=["Basica", 1 ]
            opcion=False
        else:
            print("Opcion No Valida\n")
    return tipo


# funcion para asignar una sala a un cliente
def funcion_salas(resevacion, dicSalas):
    lista=""
    for sala, datos_sala in dicSalas.items():
        if resevacion <= datos_sala[0]:
            lista=[sala, datos_sala[1]]
            return lista
       
 # funcion para calular el total
def calcularTotal(totalAlquiler, costoRestaurante):
    return totalAlquiler+costoRestaurante

def llenar(nueva):
    # variables y asignacion
    nombre=input("Ingrese el nombre del cliente: ")
    pelicula=funcion_peliculas(listaPeliculas)
    print("")
    reservacion=int(input("Ingrese la cantidad de personas del grupo: "))
    print("")
    salaAsigna=funcion_salas(reservacion, dicSala)
    sala=salaAsigna[0]
    tipo=funcion_tipoSala()
    tipoSala=tipo[0]
    precio=salaAsigna[1]*tipo[1]
    tiempo=int(input("\nIngrese la cantidad de horas: "))
    total_alquiler=funcion_total_alquiler(tiempo, precio)
    restaurante=""
    opcion=True
    while opcion==True:
        print("\n\tSeleccine Restaurante Favorito\n1. Mc-Donals\n2. El Corral\n3. Cine-Python")
        comida= int(input("Ingrese una opcion: "))
        if comida ==1:
            restaurante=comidasMAcdonal(dicComida)
            opcion=False
        elif comida ==2:
            restaurante=comidasCorral(dicComida)
            opcion=False
        elif comida==3:
            restaurante=comidasCinepython(dicComida)
            opcion=False
        else:
            print("Seleccione una opcion del 1 al 3 : ")
        print("")
    total_restaurante=restaurante[2]*reservacion
    total= calcularTotal(total_alquiler, total_restaurante)
    
    # lista auxiliar para guardar los datos en una nueva reservacion
    lista=[nombre,  pelicula, reservacion, sala, precio, tipoSala, tiempo, total_alquiler,restaurante, total_restaurante, total]
    # lista que guarda los datos de la reservacion
    nueva.append(lista)

# Mostrar datos
def mostrar(nueva, i):
    aux=""
    aux+=f"\t-----------Factura Cinepython 2022---------\n\n"
    aux+=f"Nombre: {nueva[i][0]}\n"
    aux+=f"Nombre de {nueva[i][1][2]} :{nueva[i][1][1]}\n"
    aux+=f"Reservada para : {nueva[i][2]} personas\n"
    aux+=f"Sala asignada es la N: {nueva[i][3]}\n"
    aux+=f"Tipo de Sala es:  {nueva[i][5]}\n"
    aux+=f"Precio x hora : {nueva[i][4]}\n"
    aux+=f"Tiempo de duracion es : {nueva[i][6]} horas\n"
    aux+=f"Total a Pagar por la sala es : {nueva[i][7]}\n\n"
    aux+=f"\t--------Datos del Restaurante {nueva[i][8][3]} -------\n"
    aux+=f"Combo: {nueva[i][8][0]}\n"
    aux+=f"Descripcion: {nueva[i][8][1]}\n"
    aux+=f"Valor unitario del combo : {nueva[i][8][2]}\n"
    aux+=f"Cantidad de combos: {nueva[i][2]}\n"
    aux+=f"Total a Pagar en Restaurante: {nueva[i][9]}\n\n"
    aux+=f"\tTotal a Pagar: {nueva[i][10]}\n"
    print(aux)
    funcionPdf(aux, nueva[0][0])
    print("Se ha Generado Su Factura con Exito")
#  menu principal
menu=True
while menu:
    print("---------------------------------------------------")
    print("|\tMenu Principal Bienvenido a Cine-Python   |")
    print("---------------------------------------------------")
    print("| 1. Reservar y Alquiler\t\t\t  |")
    print("| 2. Imprimir Factura\t\t\t\t  |")
    print("| 3. salir\t\t\t\t \t  |")
    print("---------------------------------------------------")
    opcion = int(input("Seleccione una opcion del 1 al 3:  "))
    print("")
    if opcion==1:
        llenar(nueva)
    elif opcion==2:
        mostrar(nueva, len(nueva)-1)
    elif opcion==3:
        print("Acaba de salir exitosamente , vuelva pronto")
        menu=False
    else:
        print("Seleccione una opcion valida")
# Out:
# ---------------------------------------------------
# |	Menu Principal Bienvenido a Cine-Python   |
# ---------------------------------------------------
# | 1. Reservar y Alquiler			  |
# | 2. Imprimir Factura				  |
# | 3. salir				 	  |
# ---------------------------------------------------
# Seleccione una opcion del 1 al 3:  1
#
# Ingrese el nombre del cliente: wendy
# 	Peliculas y Series Disponibles
# 1. Los croods 2
# 2. Tom y Jerry
# 3. Rambo
# 4. Shrek
# 5. Juego del calamar 2
# 6. La casa de papel
# 7. palpito
# Seleccione una Pelicula del 1 al 7: 7
#
# Ingrese la cantidad de personas del grupo: 6
#
# 	Tipos de Sala
# 1. Premium
# 2. Medium
# 3. Basica
# Selecione una opcion del 1 al 3: 3
#
# Ingrese la cantidad de horas: 6
#
# 	Seleccine Restaurante Favorito
# 1. Mc-Donals
# 2. El Corral
# 3. Cine-Python
# Ingrese una opcion: 1
# 	Menu Macdonals
# 1. Combo Croissant Huevo Y Tocineta Con Hashbrown 2
# 2. Combo Pancakes con Hashbrown
# 3. 1 Cajita Feliz de Nuggets
# ...
